# %%
import wave
import numpy as np

def pad_wav(input_file, output_file, target_length_seconds):
    # Open the input WAV file
    with wave.open(input_file, 'rb') as wav_in:
        # Extract the audio parameters
        params = wav_in.getparams()
        n_channels = wav_in.getnchannels()
        sample_width = wav_in.getsampwidth()
        frame_rate = wav_in.getframerate()
        n_frames = wav_in.getnframes()

        # Calculate the current duration of the audio in seconds
        current_length_seconds = n_frames / frame_rate

        # Calculate the number of frames needed to reach the target length
        target_length_frames = int(target_length_seconds * frame_rate)
        padding_frames = max(0, target_length_frames - n_frames)

        # Read the audio data
        audio_data = wav_in.readframes(n_frames)
        
        # Convert audio data to numpy array for processing
        audio_array = np.frombuffer(audio_data, dtype=np.int16)

    # Create padding (silent frames)
    padding_array = np.zeros(padding_frames * n_channels, dtype=np.int16)
    
    # Combine the original audio with the padding
    padded_audio_array = np.concatenate((audio_array, padding_array))

    # Write the padded audio to the output file
    with wave.open(output_file, 'wb') as wav_out:
        # Set the parameters for the output file
        wav_out.setparams(params)
        # Write the padded audio data
        wav_out.writeframes(padded_audio_array.tobytes())

# Example usage
input_file = 'audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit1.wav'
output_file = 'output_padded.wav'
target_length_seconds = 7.0  # Desired length in seconds

pad_wav(input_file, output_file, target_length_seconds)

# %%
import os
import wave
import numpy as np

def pad_wav(input_file, output_file, target_length_seconds):
    # Open the input WAV file
    with wave.open(input_file, 'rb') as wav_in:
        # Extract the audio parameters
        params = wav_in.getparams()
        n_channels = wav_in.getnchannels()
        sample_width = wav_in.getsampwidth()
        frame_rate = wav_in.getframerate()
        n_frames = wav_in.getnframes()

        # Calculate the current duration of the audio in seconds
        current_length_seconds = n_frames / frame_rate

        # Calculate the number of frames needed to reach the target length
        target_length_frames = int(target_length_seconds * frame_rate)
        padding_frames = max(0, target_length_frames - n_frames)

        # Read the audio data
        audio_data = wav_in.readframes(n_frames)
        
        # Convert audio data to numpy array for processing
        audio_array = np.frombuffer(audio_data, dtype=np.int16)

    # Create padding (silent frames)
    padding_array = np.zeros(padding_frames * n_channels, dtype=np.int16)
    
    # Combine the original audio with the padding
    padded_audio_array = np.concatenate((audio_array, padding_array))

    # Write the padded audio to the output file
    with wave.open(output_file, 'wb') as wav_out:
        # Set the parameters for the output file
        wav_out.setparams(params)
        # Write the padded audio data
        wav_out.writeframes(padded_audio_array.tobytes())

def pad_wav_files_in_directory(root_directory, output_directory, target_length_seconds):
    for dirpath, _, filenames in os.walk(root_directory):
        for filename in filenames:
            if filename.lower().endswith('.wav'):
                input_file = os.path.join(dirpath, filename)
                # Construct the output path
                relative_path = os.path.relpath(dirpath, root_directory)
                output_dirpath = os.path.join(output_directory, relative_path)
                os.makedirs(output_dirpath, exist_ok=True)
                output_file = os.path.join(output_dirpath, filename)
                pad_wav(input_file, output_file, target_length_seconds)
                print(f'Padded {input_file} and saved as {output_file}')

# Example usage
root_directory = 'audio_data'
output_directory = 'padded'
target_length_seconds = 7.0  # Desired length in seconds

pad_wav_files_in_directory(root_directory, output_directory, target_length_seconds)
# Out:
# Padded audio_data/train/Brass/brass_hammer_set2_hit6.wav and saved as padded/train/Brass/brass_hammer_set2_hit6.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit1.wav and saved as padded/train/Brass/brass_hammer_set2_hit1.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit20.wav and saved as padded/train/Brass/brass_hammer_set2_hit20.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit28.wav and saved as padded/train/Brass/brass_hammer_set2_hit28.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit26.wav and saved as padded/train/Brass/brass_hammer_set2_hit26.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit29.wav and saved as padded/train/Brass/brass_hammer_set2_hit29.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit22.wav and saved as padded/train/Brass/brass_hammer_set2_hit22.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit24.wav and saved as padded/train/Brass/brass_hammer_set2_hit24.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit30.wav and saved as padded/train/Brass/brass_hammer_set2_hit30.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit12.wav and saved as padded/train/Brass/brass_hammer_set2_hit12.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit2.wav and saved as padded/train/Brass/brass_hammer_set2_hit2.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit8.wav and saved as padded/train/Brass/brass_hammer_set2_hit8.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit7.wav and saved as padded/train/Brass/brass_hammer_set2_hit7.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit31.wav and saved as padded/train/Brass/brass_hammer_set2_hit31.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit3.wav and saved as padded/train/Brass/brass_hammer_set2_hit3.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit16.wav and saved as padded/train/Brass/brass_hammer_set2_hit16.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit19.wav and saved as padded/train/Brass/brass_hammer_set2_hit19.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit14.wav and saved as padded/train/Brass/brass_hammer_set2_hit14.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit18.wav and saved as padded/train/Brass/brass_hammer_set2_hit18.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit11.wav and saved as padded/train/Brass/brass_hammer_set2_hit11.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit10.wav and saved as padded/train/Brass/brass_hammer_set2_hit10.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit13.wav and saved as padded/train/Brass/brass_hammer_set2_hit13.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit25.wav and saved as padded/train/Brass/brass_hammer_set2_hit25.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit23.wav and saved as padded/train/Brass/brass_hammer_set2_hit23.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit17.wav and saved as padded/train/Brass/brass_hammer_set2_hit17.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit5.wav and saved as padded/train/Brass/brass_hammer_set2_hit5.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit9.wav and saved as padded/train/Brass/brass_hammer_set2_hit9.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit15.wav and saved as padded/train/Brass/brass_hammer_set2_hit15.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit27.wav and saved as padded/train/Brass/brass_hammer_set2_hit27.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit21.wav and saved as padded/train/Brass/brass_hammer_set2_hit21.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit4.wav and saved as padded/train/Brass/brass_hammer_set2_hit4.wav
# Padded audio_data/train/Brass/brass_hammer_set2_hit32.wav and saved as padded/train/Brass/brass_hammer_set2_hit32.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit19.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit19.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit9.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit9.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit20.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit20.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit30.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit30.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit1.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit1.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit18.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit18.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit28.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit28.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit25.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit25.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit23.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit23.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit22.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit22.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit24.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit24.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit4.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit4.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit16.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit16.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit7.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit7.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit21.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit21.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit10.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit10.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit17.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit17.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit31.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit31.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit3.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit3.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit14.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit14.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit8.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit8.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit5.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit5.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit27.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit27.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit26.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit26.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit32.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit32.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit6.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit6.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit11.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit11.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit13.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit13.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit12.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit12.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit29.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit29.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit2.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit2.wav
# Padded audio_data/train/Aluminum/circular_plate_3mm_hammer_set4_hit15.wav and saved as padded/train/Aluminum/circular_plate_3mm_hammer_set4_hit15.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit30.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit30.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit20.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit20.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit29.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit29.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit2.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit2.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit9.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit9.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit15.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit15.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit24.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit24.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit19.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit19.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit5.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit5.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit27.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit27.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit18.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit18.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit17.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit17.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit21.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit21.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit7.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit7.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit14.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit14.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit13.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit13.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit16.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit16.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit32.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit32.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit8.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit8.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit31.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit31.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit28.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit28.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit11.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit11.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit6.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit6.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit23.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit23.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit25.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit25.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit10.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit10.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit12.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit12.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit1.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit1.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit3.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit3.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit4.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit4.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit26.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit26.wav
# Padded audio_data/train/Bronze/bronze_hammer_set1_hit22.wav and saved as padded/train/Bronze/bronze_hammer_set1_hit22.wav
